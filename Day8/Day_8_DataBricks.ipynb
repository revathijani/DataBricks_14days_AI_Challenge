# %% [markdown]
# # Catalog & Schema Setup

# %%
# %sql
-- Create catalog & schemas
CREATE CATALOG ecommerce;

-- Use the catalog
USE CATALOG ecommerce;

CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# # Register Delta Tables
# **Created managed Delta tables
#
# Registered tables in each layer:
#
# bronze.events
# silver.events
# gold.products**

# %%
# %sql
USE CATALOG ecommerce;

-- BRONZE
CREATE TABLE IF NOT EXISTS bronze.events AS
SELECT
  CAST(1 AS INT)      AS event_id,
  'view'              AS event_type,
  current_timestamp() AS event_ts
UNION ALL
SELECT
  2, 'purchase', current_timestamp();

-- SILVER
CREATE TABLE IF NOT EXISTS silver.events AS
SELECT * FROM bronze.events;

-- GOLD
CREATE TABLE IF NOT EXISTS gold.products AS
SELECT
  'Product A' AS product_name,
  12000       AS revenue,
  0.12        AS conversion_rate,
  25          AS purchases
UNION ALL
SELECT
  'Product B', 8000, 0.09, 8;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM bronze.events;
SELECT * FROM silver.events;
SELECT * FROM gold.products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>revenue</th><th>conversion_rate</th><th>purchases</th></tr></thead><tbody><tr><td>Product A</td><td>12000</td><td>0.12</td><td>25</td></tr><tr><td>Product B</td><td>8000</td><td>0.09</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# # Access Control (GRANT)

# %%
# %sql
SHOW GRANTS ON TABLE gold.products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# # Controlled Access Using Views

# %%
# %sql
USE CATALOG ecommerce;

CREATE OR REPLACE VIEW gold.top_products AS
SELECT
  product_name,
  revenue,
  conversion_rate
FROM gold.products
WHERE purchases > 10
ORDER BY revenue DESC
LIMIT 100;

# %%
# %sql
SELECT * FROM gold.top_products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>revenue</th><th>conversion_rate</th></tr></thead><tbody><tr><td>Product A</td><td>12000</td><td>0.12</td></tr></tbody></table></div>

# %%
# %sql
GRANT SELECT ON VIEW gold.top_products TO `account users`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW GRANTS ON VIEW gold.top_products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>account users</td><td>SELECT</td><td>TABLE</td><td>ecommerce.gold.top_products</td></tr></tbody></table></div>
